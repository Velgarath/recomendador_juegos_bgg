# %% [markdown]
# <a href="https://colab.research.google.com/github/Velgarath/recomendador_juegos_bgg/blob/main/Copia_de_juegosBGG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PASO 0. IMPORTACION DE LIBRERIAS**

# %%
import re
import requests
import pandas as pd
import xml.etree.ElementTree as ET
import time
import os
import shutil
from google.colab import userdata
from google.colab import drive
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import numpy as np

# %% [markdown]
# **PASO 1: MONTAMOS GOOGLE DRIVE EN COLAB PARA RECUPERAR INFORMACION**

# %%
#MONTAMOS EL DRIVE DE GOOGLE
from google.colab import drive

# 1. Intentamos desmontar de forma limpia usando la herramienta de disco de Colab
try:
    drive.flush_and_unmount()
    print("Unidad desmontada limpiamente.")
except Exception as e:
    print("No se pudo desmontar de forma estándar (puede que no estuviera montado):", e)

# 2. Si quedan carpetas residuales en la ruta, las eliminamos a la fuerza
mountpoint = '/content/drive'
if os.path.exists(mountpoint):
    try:
        # Eliminamos la carpeta "drive" y todo su contenido conflictivo local
        shutil.rmtree(mountpoint)
        print(f"Carpeta residual '{mountpoint}' eliminada con éxito.")
    except Exception as e:
        print(f"No se pudo eliminar la carpeta {mountpoint} directamente: {e}")
        print("Intentando forzar la eliminación por consola...")
        # Alternativa por comandos de sistema si Python encuentra el directorio bloqueado
        # !umount -l /content/drive
        # !rm -rf /content/drive

# 3. Volvemos a montar desde cero de forma limpia
print("Volviendo a montar Drive...")
drive.mount(mountpoint)
# Out:
# Unidad desmontada limpiamente.
# Volviendo a montar Drive...
# Mounted at /content/drive

# %%
#ESTE CODIGO ME RENUEVA LOS FICHEROS DE KAGGLE DE LA BGG Y ME LOS METE EN GOOGLE DRIVE
#Importacion de la variable de entorno para conectarme a KAGGLE y descargar los datos
try:
    os.environ['KAGGLE_USERNAME'] = userdata.get('KAGGLE_USERNAME')
    os.environ['KAGGLE_KEY'] = userdata.get('KAGGLE_API_TOKEN')
    print("¡Tokens de Kaggle cargados de forma segura desde los secretos de Colab!")
except Exception as e:
    print("Error:",e)

#Descarga de los datos de la web de Kaggle
# !kaggle datasets download -d threnjen/board-games-database-from-boardgamegeek -p "/content/drive/MyDrive/Colab Notebooks/IA Juegos/Datos/" --unzip
# Out:
# ¡Tokens de Kaggle cargados de forma segura desde los secretos de Colab!
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# Dataset URL: https://www.kaggle.com/datasets/threnjen/board-games-database-from-boardgamegeek
# License(s): CC-BY-SA-3.0
# board-games-database-from-boardgamegeek.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
#LECTURA DE LOS DATOS CSV DE KAGGLE
#Leemos los ficheros de la base de datos de Kagle y los metemos en DataFrames

# Tabla principal de juegos
df_games = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IA Juegos/Datos/games.csv")
# Tabla de mecánicas
df_mechanics = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IA Juegos/Datos/mechanics.csv")
# Tabla de temáticas
df_themes = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IA Juegos/Datos/themes.csv")
# Tabla de categorías
df_subcategories = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IA Juegos/Datos/subcategories.csv")
# Tabla de diseñadores
df_designers = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IA Juegos/Datos/designers_reduced.csv")
# Tabla de editoriales
df_publishers = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IA Juegos/Datos/publishers_reduced.csv")


# Una vez leidas todas las tablas de los ficheros de Kagle, vamos a construir los dataframes que iremos evaluando
#
# df_games es el dataframe "de base". Lo tenemos listo. y le vamos añadiendo columnas progresivamente.
#
# df_games_mechanics = df_games + df_mechanics
df_games_mechanics = df_games.merge(
    df_mechanics,
    on='BGGId',
    how='left'
)
#
# df_games_themes = df_games + df_mechanics + df_themes.
df_games_themes = df_games_mechanics.merge(
    df_themes,
    on='BGGId',
    how='left'
)
#
# df_games_subcategories = df_games + df_mechanics + df_themes + df_subcategories
df_games_subcategories = df_games_themes.merge(
    df_subcategories,
    on='BGGId',
    how='left'
)
#
# df_games_designers = df_games + df_mechanics + df_themes + df_subcategories + df_designers
df_games_designers = df_games_subcategories.merge(
    df_designers,
    on='BGGId',
    how='left'
)
#
# df_games_publishers = df_games + df_mechanics + df_themes + df_subcategories + df_designers + df_publishers
df_games_publishers = df_games_designers.merge(
    df_publishers,
    on='BGGId',
    how='left'
)
#

# %%
# LECTURA DE LOS DATOS DE LA BGG
# Este link descarga el XML de los juegos que poseo. NO inlcuye expansiones
# https://boardgamegeek.com/xmlapi2/collection?username=velgarath&subtype=boardgame&excludesubtype=boardgameexpansion&own=1
# Este link descarga el XML de los juegos que he puntuado en la BGG independientemente de si los tengo o no los tengo. No incluye expansiones.
# https://boardgamegeek.com/xmlapi2/collection?username=velgarath&subtype=boardgame&excludesubtype=boardgameexpansion&rated=1


#Esta funcion es necesaria para limpiar los ampersands del XML
#Es un problema conocido de la exportacion de los XML de la BGG
def limpia_ampersands(texto_xml):
    # Reemplaza & que NO sea parte de una entidad válida (&amp; &lt; &gt; &quot; &apos; &#123; &#x1F;)
    return re.sub(r'&(?!amp;|lt;|gt;|quot;|apos;|#\d+;|#x[0-9a-fA-F]+;)', '&amp;', texto_xml)

#drive.mount('/content/drive', force_remount=True)

# Abrimos por separado los juegos poseidos por luis y los juegos puntuiados por luis
f = open("/content/drive/MyDrive/Colab Notebooks/IA Juegos/Datos/velgarath_games_owned.xml", "r")
juegos_owned_luis = limpia_ampersands(f.read())
f.close()

f = open("/content/drive/MyDrive/Colab Notebooks/IA Juegos/Datos/velgarath_games_rated.xml", "r")
juegos_rated_luis = limpia_ampersands(f.read())
f.close()

# %%
# PARSEADO XML DE UNA COLECCION DE JUEGOS DE MESA IMPORTADO DE LA BGG

def convierte_xml_a_dataframe(respuesta):
    raiz = ET.fromstring(respuesta)
    lista_juegos = []

    for item in raiz.findall('item'):
        objectid = item.attrib.get('objectid')  # clave para el merge con Kaggle
        subtype = item.attrib.get('subtype')

        name = item.find('name').text if item.find('name') is not None else 'Desconocido'
        year = item.find('yearpublished').text if item.find('yearpublished') is not None else 'N/A'
        numplays = item.find('numplays').text if item.find('numplays') is not None else 'N/A'

        status = item.find('status')
        own = status.attrib.get('own') if status is not None else None
        wishlist = status.attrib.get('wishlist') if status is not None else None
        preordered = status.attrib.get('preordered') if status is not None else None

        # stats puede faltar según cómo se exportó el XML, así que protegemos todo
        stats = item.find('stats')
        if stats is not None:
            min_players = stats.attrib.get('minplayers')
            max_players = stats.attrib.get('maxplayers')
            playing_time = stats.attrib.get('playingtime')
            num_owned = stats.attrib.get('numowned')
            etiqueta_rating = stats.find('rating')
            user_rating = etiqueta_rating.attrib.get('value') if etiqueta_rating is not None else 'N/A'
            average_elem = stats.find('rating/average')
            avg_rating = average_elem.attrib.get('value') if average_elem is not None else None
        else:
            min_players = max_players = playing_time = num_owned = None
            user_rating = 'N/A'
            avg_rating = None

        lista_juegos.append({
            'BGGId': objectid,
            'Subtype': subtype,
            'IsExpansion': subtype == 'boardgameexpansion',
            'Name': name,
            'YearPublished': year,
            'AvgRating': avg_rating,
            'UserRating': user_rating,
            'MinPlayers': min_players,
            'MaxPlayers': max_players,
            'PlayingTime': playing_time,
            'NumOwned': num_owned,
            'NumPlays': numplays,
            'Own': own,
            'Wishlist': wishlist,
            'Preordered': preordered,
        })

    df_lista_juegos = pd.DataFrame(lista_juegos)

    columns_to_convert = ['YearPublished', 'AvgRating', 'UserRating',
                          'MinPlayers', 'MaxPlayers',
                          'PlayingTime', 'NumOwned', 'NumPlays']
    df_lista_juegos[columns_to_convert] = df_lista_juegos[columns_to_convert].apply(pd.to_numeric, errors='coerce')
    df_lista_juegos['BGGId'] = pd.to_numeric(df_lista_juegos['BGGId'], errors='coerce').astype('Int64')

    return df_lista_juegos

# Creamos 2 dataframes
# el data frame RATED lo usaremos para entrenar el modelo.
# el data frame OWNED no lo usaremos en la fase de aprendizaje. Lo usaremos para ver qué juegos de los que recomienda el modelo YA lo tenemos.
df_rated = convierte_xml_a_dataframe(juegos_rated_luis)
df_owned = convierte_xml_a_dataframe(juegos_owned_luis)

#Hemos visto que el tipo BGG_ID es "Int64". Lo pasamos a "int64 para que sea igual de la BD de Kagle"
df_owned['BGGId'] = df_owned['BGGId'].astype('int64')
df_rated['BGGId'] = df_rated['BGGId'].astype('int64')

print("Ratings válidos en OWNED:", df_owned['UserRating'].notna().sum())
print("Ratings válidos en RATED:", df_rated['UserRating'].notna().sum())
# Out:
# Ratings válidos en OWNED: 222
# Ratings válidos en RATED: 279

# %%
# ==============================================================
# PREPARACIÓN DE LOS DATAFRAMES DE ENTRENAMIENTO
# ==============================================================

# df_rated contiene exclusivamente los juegos base que he puntuado,
# independientemente de si los poseo actualmente o no.
#
# De df_rated solo necesitamos:
#   - BGGId: clave para cruzar con la base global de juegos
#   - UserRating: mi puntuación, que será el objetivo "y" del modelo
#
# Transformamos algunas características de games.csv antes de entrenar:
#   - YearPublished se convierte en periodos.
#   - Family se transforma mediante one-hot encoding.
#
# Después construimos dataframes progresivamente más "anchos"
# añadiendo nuevas familias de características de Kaggle.


cols_luis = ['BGGId', 'UserRating']


# ==============================================================
# TRANSFORMACIÓN DE YearPublished
# ==============================================================

bins = [
    -float('inf'),
    1979,
    1989,
    1999,
    2009,
    2019,
    float('inf')
]

labels = [
    'Pre1980',
    '1980s',
    '1990s',
    '2000s',
    '2010s',
    '2020s'
]

df_games['YearPeriod'] = pd.cut(
    df_games['YearPublished'],
    bins=bins,
    labels=labels
)

df_year = pd.get_dummies(
    df_games[['BGGId', 'YearPeriod']],
    columns=['YearPeriod'],
    dtype=int
)


# ==============================================================
# ONE-HOT ENCODING DE Family
# ==============================================================

df_family = pd.get_dummies(
    df_games[['BGGId', 'Family']],
    columns=['Family'],
    dummy_na=False,
    dtype=int
)


# ==============================================================
# AÑADIMOS LAS TRANSFORMACIONES A df_games
# ==============================================================

df_games_encoded = df_games.merge(
    df_year,
    on='BGGId',
    how='left'
)

df_games_encoded = df_games_encoded.merge(
    df_family,
    on='BGGId',
    how='left'
)


# ==============================================================
# DATAFRAME BASE DE ENTRENAMIENTO
# ==============================================================

df_train = df_rated[cols_luis].merge(
    df_games_encoded,
    on='BGGId',
    how='inner'
)


# Sustituimos valores ausentes por la mediana de la columna.
df_train['ComAgeRec'] = df_train['ComAgeRec'].fillna(
    df_train['ComAgeRec'].median()
)

df_train['LanguageEase'] = df_train['LanguageEase'].fillna(
    df_train['LanguageEase'].median()
)


# ==============================================================
# DATAFRAMES DE ENTRENAMIENTO PROGRESIVAMENTE MÁS ANCHOS
# ==============================================================

df_train_mechanics = df_train.merge(
    df_mechanics,
    on='BGGId',
    how='left'
)

df_train_themes = df_train_mechanics.merge(
    df_themes,
    on='BGGId',
    how='left'
)

df_train_subcategories = df_train_themes.merge(
    df_subcategories,
    on='BGGId',
    how='left'
)

df_train_designers = df_train_subcategories.merge(
    df_designers,
    on='BGGId',
    how='left'
)

df_train_publishers = df_train_designers.merge(
    df_publishers,
    on='BGGId',
    how='left'
)

# %%
# LANZAMOS EL MACHINE LEARNING
# Creamos la matriz de parámetros X y el vector y de respuestas.

features = [
    'GameWeight', 'MinPlayers', 'MaxPlayers', 'MfgPlaytime',
    'ComMinPlaytime', 'ComMaxPlaytime', 'ComAgeRec', 'LanguageEase',
    'Cat:Thematic', 'Cat:Strategy', 'Cat:War', 'Cat:Family',
    'Cat:CGS', 'Cat:Abstract', 'Cat:Party', 'Cat:Childrens'
]

features_year = [
    columna for columna in df_year.columns
    if columna != 'BGGId'
]
features_family = [
    columna for columna in df_family.columns
    if columna != 'BGGId'
]

features_games = [
    'GameWeight',
    'MinPlayers',
    'MaxPlayers',
    'MfgPlaytime',
    'ComMinPlaytime',
    'ComMaxPlaytime',
    'ComAgeRec',
    'LanguageEase',
    'MfgAgeRec',
    'NumAlternates',
    'NumExpansions',
    'NumImplementations',
    'IsReimplementation',
    'Kickstarted',
    'Cat:Thematic',
    'Cat:Strategy',
    'Cat:War',
    'Cat:Family',
    'Cat:CGS',
    'Cat:Abstract',
    'Cat:Party',
    'Cat:Childrens'
]

features_games_encoded = (
    features_games
    + features_year
    + features_family
)



X = df_train[features_games_encoded]
y = df_train['UserRating']


# ==============================================================
# BASELINE: PREDECIR SIEMPRE LA NOTA MEDIA
# ==============================================================

modelo_dummy = DummyRegressor(strategy='mean')

scores_dummy = cross_val_score(
    modelo_dummy,
    X,
    y,
    cv=5,
    scoring='neg_mean_absolute_error'
)

mae_dummy = -scores_dummy.mean()


# ==============================================================
# REGRESIÓN LINEAL
# ==============================================================

modelo = LinearRegression()

# Scikit-learn devuelve el MAE negativo por convención.
scores = cross_val_score(
    modelo,
    X,
    y,
    cv=5,
    scoring='neg_mean_absolute_error'
)

mae_modelo = -scores.mean()

# Entrenamos con todos los datos para inspeccionar los pesos.
modelo.fit(X, y)

pesos = pd.Series(
    modelo.coef_,
    index=X.columns
).sort_values()


# ==============================================================
# RIDGE
# ==============================================================

# El pipeline estandariza las variables antes de aplicar Ridge.
modelo_ridge = make_pipeline(
    StandardScaler(),
    Ridge(alpha=1.0)
)

scores_ridge = cross_val_score(
    modelo_ridge,
    X,
    y,
    cv=5,
    scoring='neg_mean_absolute_error'
)

mae_ridge = -scores_ridge.mean()

modelo_ridge.fit(X, y)

pesos_ridge = pd.Series(
    modelo_ridge.named_steps['ridge'].coef_,
    index=X.columns
).sort_values()


# ==============================================================
# RESUMEN LEGIBLE DE RESULTADOS
# ==============================================================

#Hacemos un data_frame que contiene los resultados de cada modelo.
comparacion_modelos = pd.DataFrame({
    'Modelo': [
        'Dummy (media)',
        'Regresión lineal',
        'Ridge'
    ],
    'MAE': [
        mae_dummy,
        mae_modelo,
        mae_ridge
    ],
    'Mejora vs baseline': [
        0.0,
        mae_dummy - mae_modelo,
        mae_dummy - mae_ridge
    ]
})

print('\n' + '=' * 68)
print('COMPARACIÓN DEL RENDIMIENTO DE LOS MODELOS')
print('=' * 68)

print(
    comparacion_modelos.to_string(
        index=False,
        formatters={
            'MAE': lambda valor: f'{valor:.3f}',
            'Mejora vs baseline': lambda valor: f'{valor:+.3f}'
        }
    )
)

print('\nCuanto menor es el MAE, mejor predice el modelo.')







# ==============================================================
# RESULTADOS DE CADA PLIEGUE
# ==============================================================

print('\n' + '-' * 68)
print('MAE EN CADA PLIEGUE DE LA VALIDACIÓN CRUZADA')
print('-' * 68)

print(f"Dummy            : {(-scores_dummy).round(3)}")
print(f"Regresión lineal : {(-scores).round(3)}")
print(f"Ridge            : {(-scores_ridge).round(3)}")

# ==============================================================
# COEFICIENTES
# ==============================================================

print('\n' + '-' * 68)
print('COEFICIENTES APRENDIDOS')
print('-' * 68)

print('\nRegresión lineal:')
print(pesos.to_string())

print('\nRidge (variables estandarizadas):')
print(pesos_ridge.to_string())
# Out:
# ====================================================================
# COMPARACIÓN DEL RENDIMIENTO DE LOS MODELOS
# ====================================================================
#           Modelo   MAE Mejora vs baseline
#    Dummy (media) 1.651             +0.000
# Regresión lineal 1.773             -0.123
#            Ridge 1.702             -0.052
#
# Cuanto menor es el MAE, mejor predice el modelo.
#
# --------------------------------------------------------------------
# MAE EN CADA PLIEGUE DE LA VALIDACIÓN CRUZADA
# --------------------------------------------------------------------
# Dummy            : [1.588 1.728 1.638 1.579 1.719]
# Regresión lineal : [1.562 1.45  1.868 1.941 2.044]
# Ridge            : [1.471 1.444 1.817 1.807 1.972]
#
# --------------------------------------------------------------------
# COEFICIENTES APRENDIDOS
# --------------------------------------------------------------------
#
# Regresión lineal:
# Family_GoPlay                                                            -4.993317e+00
# Family_Jungle Speed                                                      -4.129515e+00
# YearPeriod_Pre1980                                                       -4.066918e+00
# Family_Rory's Story Cubes                                                -3.919511e+00
# Family_Maracaibo                                                         -3.782307e+00
# Family_BANG!                                                             -3.740809e+00
# Family_Through the Ages                                                  -3.657744e+00
# Family_The Voyages of Marco Polo                                         -3.596730e+00
# Family_Mr. Jack                                                          -3.097036e+00
# Family_Ingenious                                                         -3.020155e+00
# Cat:Childrens                                                            -2.834261e+00
# Family_Fantasy Flight Big Box                                            -2.756075e+00
# Family_Small World                                                       -2.717584e+00
# Family_The Gold Trilogy (Michael Schacht)                                -2.714508e+00
# Family_Ca$h 'n Gun$                                                      -2.453750e+00
# Family_NSV Middys (Nürnberger Spielkartenverlag)                         -2.435807e+00
# Family_Nostalgia (Hasbro)                                                -2.325750e+00
# Family_Wingspan                                                          -1.815310e+00
# Family_Native-art line (Kosmos)                                          -1.735065e+00
# Family_Saboteur                                                          -1.648594e+00
# Family_GIPF Project                                                      -1.502221e+00
# Family_Blokus                                                            -1.173291e+00
# Family_RWB (Valley Games)                                                -1.164278e+00
# Family_Harvest (Uwe Rosenberg)                                           -1.106392e+00
# Family_Nations                                                           -1.104436e+00
# Family_Gloomhaven                                                        -1.096240e+00
# Family_Blue Games (Descartes)                                            -1.051657e+00
# Family_Dungeon Twister                                                   -1.009122e+00
# Family_Hiv                                                               -9.576287e-01
# Family_Pandemic                                                          -9.048078e-01
# Family_Literature (Kosmos)                                               -8.227794e-01
# Family_Bean Games (Lookout)                                              -8.203433e-01
# Cat:Thematic                                                             -7.502897e-01
# Cat:Family                                                               -6.900631e-01
# Family_Alien Frontiers                                                   -5.515352e-01
# Family_Web of Power / China                                              -5.376839e-01
# Family_Innovation                                                        -5.148357e-01
# Family_Euro Games (Victory Point Games)                                  -4.764878e-01
# Family_Villag                                                            -4.735718e-01
# Family_Camel Up                                                          -4.511493e-01
# Kickstarted                                                              -4.373006e-01
# Family_Dominant Species                                                  -3.808516e-01
# Family_Arkham Horror Files (Fantasy Flight Games)                        -3.346825e-01
# Family_Power Grid                                                        -2.834352e-01
# Family_Brass                                                             -2.720717e-01
# Family_Qwirkl                                                            -2.384318e-01
# Family_Twilight Struggl                                                  -2.097562e-01
# Family_One Night (Bézier Games)                                          -1.997285e-01
# MinPlayers                                                               -1.947552e-01
# Family_Mystery of the Abbey                                              -1.780343e-01
# Family_Alhambr                                                           -1.629212e-01
# Family_The Gallerist                                                     -1.244452e-01
# ComAgeRec                                                                -1.081839e-01
# Family_Basic (Gigamic)                                                   -7.743557e-02
# MaxPlayers                                                               -3.658182e-02
# NumExpansions                                                            -2.012658e-02
# Family_Ystari original                                                   -1.848550e-02
# ComMinPlaytime                                                           -2.765063e-03
# LanguageEase                                                             -1.435588e-03
# MfgPlaytime                                                              -8.152264e-05
# ComMaxPlaytime                                                           -8.152264e-05
# Family_007 James Bond Action Episode Gam                                 -1.020426e-10
# Family_10 Days in ...                                                    -6.956641e-11
# Family_... in my Pocket                                                  -2.560585e-11
# Family_3M Paper Games                                                    -1.146594e-11
# Family_6 nimmt!                                                          -8.570034e-12
# Family_5-Minute (Connor Reid)                                            -7.712331e-12
# Family_A to Z (Tactic)                                                   -6.331713e-12
# Family_100 Swords                                                        -5.654588e-12
# Family_1914 (GMT)                                                        -4.449774e-12
# Family_50 Clu                                                            -4.191314e-12
# Family_24 Gam                                                            -4.144962e-12
# Family_AT-43                                                             -3.894662e-12
# Family_5150 Science Fiction Wargam                                       -3.848921e-12
# Family_51st Stat                                                         -3.245626e-12
# Family_Aeon's End                                                        -3.221423e-12
# Family_60's 70's 80's 90's (Start Space Games)                           -2.860268e-12
# Family_12 Realms                                                         -2.744596e-12
# Family_3M Bookshelf                                                      -2.477907e-12
# Family_A Song of Ice & Fire – Tabletop Miniatures                        -2.437606e-12
# Family_Aether Captains                                                   -1.432632e-12
# Family_A Game of Thrones – The Board                                     -1.413258e-12
# Family_ARC System                                                        -1.407541e-12
# Family_Activity (Piatnik)                                                -1.195710e-12
# Family_Abyss (Bombyx)                                                    -7.196466e-13
# Family_Agricol                                                           -6.348533e-13
# Family_AMIGO dice games in box                                           -6.188383e-13
# Family_Bezzerwizzer                                                      -5.992290e-13
# Family_Anno Domini 1666                                                  -4.125034e-13
# Family_Army vs. Aliens                                                   -3.982925e-13
# Family_American Revolution Campaigns (Worthington Games)                 -3.757550e-13
# Family_Aristeia!                                                         -3.547163e-13
# Family_Ambush! solitaire wargame system (Victory Games)                  -3.270717e-13
# Family_A la charge (Vae Victis)                                          -2.993161e-13
# Family_Active Kids (HABA)                                                -2.977618e-13
# Family_Abstract (Lakeside)                                               -2.876033e-13
# Family_Anachrony                                                         -2.513545e-13
# Family_Altar of Freedo                                                   -2.430833e-13
# Family_Anima Tactics                                                     -2.331468e-13
# Family_Analog Apps (Fisher Heaton)                                       -1.971201e-13
# Family_Ancient Anthology (Garphill Games)                                -1.456613e-13
# Family_Alias                                                             -1.324496e-13
# Family_Atmosfear                                                         -1.166224e-13
# Family_Black Stories                                                     -1.054296e-13
# Family_American Heritage (Milton Bradley)                                -1.040557e-13
# Family_Auto Racing card system (Wolfgang Kramer)                         -1.020364e-13
# Family_BattleTech                                                        -9.808820e-14
# Family_Arcadia Quest                                                     -9.769963e-14
# Family_Battlegroup Rul                                                   -9.348078e-14
# Family_Ave Ro                                                            -9.103829e-14
# Family_Attack!                                                           -8.472639e-14
# Family_221B Baker Street                                                 -8.126833e-14
# Family_Axis & Allies (Avalon Hill)                                       -7.727152e-14
# Family_Advanced Tobruk System (Critical Hit)                             -7.638334e-14
# Family_Arn                                                               -7.438494e-14
# Family_Battles of the Ancient World (Decision Game)                      -7.099876e-14
# Family_Battles for North Africa (3W)                                     -6.952772e-14
# Family_Altiplano                                                         -6.334690e-14
# Family_Beyond the Gates of Antares                                       -5.540013e-14
# Family_Ancient Conflict (Playford Games)                                 -5.284662e-14
# Family_Black Seas (Warlord Games)                                        -5.151435e-14
# Family_Articulate!                                                       -5.004937e-14
# Family_B-Movies (Z-Man)                                                  -4.757306e-14
# Family_Betrayal (Avalon Hill)                                            -3.896883e-14
# Family_Brainwaves                                                        -3.408385e-14
# Family_Battlestar Galactica – Starship Battles                           -3.386180e-14
# Family_Battles of the American Revolution (GMT)                          -3.208545e-14
# Family_Atlantis (Leo Colovini)                                           -2.997602e-14
# Family_Banana Republic Finance (Capital Gains Studio)                    -2.559064e-14
# Family_Black Powder (Warlord Games)                                      -2.520206e-14
# Family_Big Deal (Patch)                                                  -2.500777e-14
# Family_Ausgerechnet ...                                                  -2.494879e-14
# Family_Boss Monster                                                      -2.242651e-14
# Family_Bloody Civil War (Paul Koenig)                                    -2.242651e-14
# Family_Age of Muskets (Bellica Third Generation)                         -2.176037e-14
# Family_Between Two Castles of Mad King Ludwig                            -2.087219e-14
# Family_Britannia Game System                                             -2.042810e-14
# Family_Arkham Horror                                                     -1.965095e-14
# Family_Battleground Fantasy Warfar                                       -1.887379e-14
# Family_Betting Trilogy (Reiner Knizia)                                   -1.754152e-14
# Family_Black Sea * Black Death                                           -1.738887e-14
# Family_Bitter Victory                                                    -1.232348e-14
# Family_Blood Red Skies                                                   -1.210143e-14
# Family_American Civil War (Mayfair)                                      -1.199041e-14
# Family_Break In (PlayMonster)                                            -1.176836e-14
# Family_BoardGameGeek                                                     -1.170339e-14
# Family_Boomerang (Grail Games)                                           -1.009391e-14
# Family_Blocks (VentoNuovo)                                               -9.325873e-15
# Family_Birds of Prey (Ad Astra Games)                                    -9.159340e-15
# Family_Big in Japan (AEG)                                                -8.229528e-15
# Family_Bottom of the 9th                                                 -6.989233e-15
# Family_Brainbox                                                          -6.478189e-15
# Family_Board Royale – The Island                                         -5.810773e-15
# Family_Blood Bowl                                                        -5.551115e-15
# Family_Anno Domini                                                       -3.885781e-15
# Family_Bunny Kingdo                                                      -3.241294e-15
# Family_Blood and Steel                                                   -2.891155e-15
# Family_Buchkassette (Pelikan)                                            -2.590507e-15
# Family_Brain Quest                                                       -2.191194e-15
# Family_Battalion Combat Series (MMP)                                     -1.984524e-15
# Family_Blurt!                                                            -1.866635e-15
# Family_Call to Adventur                                                  -1.157846e-15
# Family_All Things Zombi                                                  -4.440892e-16
# Family_Brass Empir                                                       -3.994904e-16
# Family_Berserk (Hobby World)                                             -3.330669e-16
# Family_British vs. Pirates                                               -2.689446e-16
# Family_Blood Rag                                                         -2.220446e-16
# Family_Camelot (Abstract games)                                          -4.535950e-30
# Family_Campaigns In The Valley (Robert G. Markham)                       -1.577722e-30
# Family_Queen Kid                                                          0.000000e+00
# Family_Rack-O                                                             0.000000e+00
# Family_Raccoon Tycoon                                                     0.000000e+00
# Family_Rabbit Line (Dice Hate Me Games)                                   0.000000e+00
# Family_R                                                                  0.000000e+00
# Family_Qwixx                                                              0.000000e+00
# Family_Quizzard                                                           0.000000e+00
# Family_QuickStrik                                                         0.000000e+00
# Family_Quest Master                                                       0.000000e+00
# Family_Quest (Grow)                                                       0.000000e+00
# Family_Power Politics (SPI)                                               0.000000e+00
# Family_Quartermaster                                                      0.000000e+00
# Family_Quarriors Pool Building system                                     0.000000e+00
# Family_Pocket Line (Stronghold)                                           0.000000e+00
# Family_Pocket Games series (Kozak Games)                                  0.000000e+00
# Family_Pocket Games (Task Force Games)                                    0.000000e+00
# Family_Pocket Games (Helvetiq)                                            0.000000e+00
# Family_Quads (SPI)                                                        0.000000e+00
# Family_Quadropolis                                                        0.000000e+00
# Family_Q-bitz                                                             0.000000e+00
# Family_Rapid Fire!                                                        0.000000e+00
# Family_Quantum Games (Ragnar Brothers)                                    0.000000e+00
# Family_Revolver                                                           0.000000e+00
# Family_Revolution!                                                        0.000000e+00
# Family_Reverse Charades                                                   0.000000e+00
# Family_Red Poppies Campaign                                               0.000000e+00
# Family_Red Dragon Rising System                                           0.000000e+00
# Family_Rebels & Redcoats                                                  0.000000e+00
# Family_Reaction System                                                    0.000000e+00
# Family_Rattus                                                             0.000000e+00
# Family_Q System – Sherlock (GDM Games)                                    0.000000e+00
# Family_Rangers of Shadow Deep                                             0.000000e+00
# Family_Rajas of the Ganges                                                0.000000e+00
# Family_Railways of the World                                              0.000000e+00
# Family_Railway Rivals                                                     0.000000e+00
# Family_Railroad Ink                                                       0.000000e+00
# Family_Railroad Dic                                                       0.000000e+00
# Family_Pre-School Skills Builder Games (Peaceable Kingdom)                0.000000e+00
# Family_Prairie Railroads (Winsome)                                        0.000000e+00
# Family_Pocket Detectives (Lavka games)                                    0.000000e+00
# Family_Police Precinct                                                    0.000000e+00
# Family_Poker Suite (Cheapass Games)                                       0.000000e+00
# Family_Pogs                                                               0.000000e+00
# Family_PocketPlay (Pegasus)                                               0.000000e+00
# Family_Peloponnesian War (Vae Victis)                                     0.000000e+00
# Family_Peiper Postcards (LPS)                                             0.000000e+00
# Family_Pegasus Children's Games (Matagot)                                 0.000000e+00
# Family_Pax                                                                0.000000e+00
# Family_Pocket Game (AEG)                                                  0.000000e+00
# Family_Port Royal                                                         0.000000e+00
# Family_Pocket Campaigns (Surprised Stare Games)                           0.000000e+00
# Family_Pocket Box (Steve Jackson Games)                                   0.000000e+00
# Family_Pocket Battles (Z-Man)                                             0.000000e+00
# Family_Pocket Battle Games (LPS)                                          0.000000e+00
# Family_Play the classics (Gen-X Games)                                    0.000000e+00
# Family_Play & Go (Thundergryph)                                           0.000000e+00
# Family_Pizza Box Sports (On The Line Game Company)                        0.000000e+00
# Family_Pixel Tactics                                                      0.000000e+00
# Family_PitchCar                                                           0.000000e+00
# Family_Pim Pam Pet                                                        0.000000e+00
# Family_Puzzle Trilogy (Uwe Rosenberg)                                     0.000000e+00
# Family_Puzzle Postcards (Enigma Emporium)                                 0.000000e+00
# Family_Pure Card Line (Small Box Games)                                   0.000000e+00
# Family_Puppet Wars                                                        0.000000e+00
# Family_Pub (Crash Games)                                                  0.000000e+00
# Family_Project ELITE                                                      0.000000e+00
# Family_Problem Picnic                                                     0.000000e+00
# Family_Privacy                                                            0.000000e+00
# Family_Pinkalicious (Fundex)                                              0.000000e+00
# Family_Ring of Fire (Kokusai-Tsushin)                                     0.000000e+00
# Family_Pile-Omino (nestorgames)                                           0.000000e+00
# Family_Pictures                                                           0.000000e+00
# Family_Pouch Series Game (SDC)                                            0.000000e+00
# Family_Potion Explosion                                                   0.000000e+00
# Family_Postcard (Button Shy)                                              0.000000e+00
# Family_Ports of Europe (Hans van Tol)                                     0.000000e+00
# Family_Portable Adventures (Third World Games)                            0.000000e+00
# Family_Port-A-Party (Gamewright)                                          0.000000e+00
# Family_Shadows of Brimston                                                0.000000e+00
# Family_Shuffling Horro                                                    0.000000e+00
# Family_Shuffle Card Games (Cartamundi / Hasbro)                           0.000000e+00
# Family_Shopping List                                                      0.000000e+00
# Family_Shipwreck (Martin Bourne)                                          0.000000e+00
# Family_Santorini                                                          0.000000e+00
# Family_Santa Mari                                                         0.000000e+00
# Family_Santa F                                                            0.000000e+00
# Family_San Guo Sh                                                         0.000000e+00
# Family_Salvo! naval system (Minden)                                       0.000000e+00
# Family_Shuffling the Deck (WizKids)                                       0.000000e+00
# Family_Shadows Upon Lassadar                                              0.000000e+00
# Family_Shabadabad                                                         0.000000e+00
# Family_Seven Hex System (Steven Pole)                                     0.000000e+00
# Family_Seven Days to the Rhin                                             0.000000e+00
# Family_Set                                                                0.000000e+00
# Family_Sergeants! (Lost Battalion Games)                                  0.000000e+00
# Family_Sergeants Miniatures                                               0.000000e+00
# Family_Sequenc                                                            0.000000e+00
# Family_Sentinel                                                           0.000000e+00
# Family_Sen So                                                             0.000000e+00
# Family_Small Box Big Fun (Action Phase Games)                             0.000000e+00
# Family_Small Box (Level 99 Games)                                         0.000000e+00
# Family_Sleeping Gods                                                      0.000000e+00
# Family_Slavik                                                             0.000000e+00
# Family_Skull Tales                                                        0.000000e+00
# Family_Skittle (Aurora)                                                   0.000000e+00
# Family_Skirmish Games (Too Fat Lardies)                                   0.000000e+00
# Family_Senior Premium (Noris Spiele)                                      0.000000e+00
# Family_Senior (Cadaco)                                                    0.000000e+00
# Family_Royalists & Roundheads System (3W)                                 0.000000e+00
# Family_Secrets of the Lost Tomb                                           0.000000e+00
# Family_Second World War at Sea (Avalanche Press)                          0.000000e+00
# Family_Seasons                                                            0.000000e+00
# Family_Similo                                                             0.000000e+00
# Family_Silver                                                             0.000000e+00
# Family_Silent Death                                                       0.000000e+00
# Family_Sid Sackson pencil and paper collection                            0.000000e+00
# Family_Sid Meier's Civilization                                           0.000000e+00
# Family_Rolit                                                              0.000000e+00
# Family_Runebound (Fantasy Flight Games)                                   0.000000e+00
# Family_Rune Stones                                                        0.000000e+00
# Family_Rummikub                                                           0.000000e+00
# Family_Rum & Bones                                                        0.000000e+00
# Family_Radiant Cultural Series (HeidelBÄR)                                0.000000e+00
# Family_Rolling (Hisashi Hayashi)                                          0.000000e+00
# Family_Roll Through the Ages (Matt Leacock)                               0.000000e+00
# Family_Roll & Write (Mattel)                                              0.000000e+00
# Family_Roll & Play (Schmidt Spiele)                                       0.000000e+00
# Family_Russian Railroads                                                  0.000000e+00
# Family_Rodzinka wygrywa (Egmont Polska)                                   0.000000e+00
# Family_Rococo                                                             0.000000e+00
# Family_Robinson Crusoe – Adventures on the Cursed Island                  0.000000e+00
# Family_Roads through WWII (Hexasim)                                       0.000000e+00
# Family_Road Trip (Aquarius)                                               0.000000e+00
# Family_Risk-Lik                                                           0.000000e+00
# Family_Risk (Official)                                                    0.000000e+00
# Family_Rising Sun                                                         0.000000e+00
# Family_RisiKo!                                                            0.000000e+00
# Family_Schotten-Totten                                                    0.000000e+00
# Family_Royal horror card games (Schmidt Spiele)                           0.000000e+00
# Family_Root                                                               0.000000e+00
# Family_Rome at War (Avalanche Press)                                      0.000000e+00
# Family_Rolling Freight (APE)                                              0.000000e+00
# Family_Scyth                                                              0.000000e+00
# Family_Scrabbl                                                            0.000000e+00
# Family_Scoundrel                                                          0.000000e+00
# Family_Science Games (Genius Games)                                       0.000000e+00
# Family_Schätzen Sie mal! (HUCH!)                                          0.000000e+00
# Family_Piquet – Master Rules for Wargaming                                0.000000e+00
# Family_Scene It?                                                          0.000000e+00
# Family_Scattergories                                                      0.000000e+00
# Family_Scary Tales                                                        0.000000e+00
# Family_Say Anything                                                       0.000000e+00
# Family_Rifles in ... (Tiny Battle Publishing)                             0.000000e+00
# Family_Sails of Glory                                                     0.000000e+00
# Family_Sagrad                                                             0.000000e+00
# Family_Sag                                                                0.000000e+00
# Family_Mini Games (IELLO)                                                 0.000000e+00
# Family_Monopoly-Lik                                                       0.000000e+00
# Family_Monopoly Derivatives (Official)                                    0.000000e+00
# Family_Mint (Five24 Labs/Poketto)                                         0.000000e+00
# Family_Minigames (TSR)                                                    0.000000e+00
# Family_Minigame Library (Level 99 Games)                                  0.000000e+00
# Family_MiniMonF                                                           0.000000e+00
# Family_MiniGames (Drumond Park)                                           0.000000e+00
# Family_Mini WWII (Formosa Force Games)                                    0.000000e+00
# Family_Mini Series (Decision Games)                                       0.000000e+00
# Family_Monster Maker (Arclight)                                           0.000000e+00
# Family_Mini (Ravensburger)                                                0.000000e+00
# Family_MindTrap                                                           0.000000e+00
# Family_Mille Bornes                                                       0.000000e+00
# Family_MicroHistory (Metagaming)                                          0.000000e+00
# Family_Men of Iron (GMT)                                                  0.000000e+00
# Family_MechWar 2 (SPI)                                                    0.000000e+00
# Family_Math Dic                                                           0.000000e+00
# Family_Matchbox Games (Helvetiq)                                          0.000000e+00
# Family_Match the most and win! (Scala leuker leren)                       0.000000e+00
# Family_Mysthea                                                            0.000000e+00
# Family_Mitbringspiele S (HABA)                                            0.000000e+00
# Family_Mitbringspiele M (HABA)                                            0.000000e+00
# Family_Napoleonic Brigade (MMP)                                           0.000000e+00
# Family_Napoleonic 20 (Victory Point Games)                                0.000000e+00
# Family_Napoleonic (SimTac)                                                0.000000e+00
# Family_Napoleon At Waterloo (SPI)                                         0.000000e+00
# Family_Napoleon & the Archduke Charles (3W)                               0.000000e+00
# Family_Myths at War                                                       0.000000e+00
# Family_Myth (Mercs LLC)                                                   0.000000e+00
# Family_Match Up! (Randolph)                                               0.000000e+00
# Family_Mystery Rummy                                                      0.000000e+00
# Family_Mysteriu                                                           0.000000e+00
# Family_Murder à la cart                                                   0.000000e+00
# Family_Murano                                                             0.000000e+00
# Family_Munchkin                                                           0.000000e+00
# Family_Mouse Trap                                                         0.000000e+00
# Family_Monuments – Wonders of Antiquity                                   0.000000e+00
# Family_Monsterfalle (Kosmos)                                              0.000000e+00
# Family_Lunchbox (Inside the Box)                                          0.000000e+00
# Family_Mad Gab                                                            0.000000e+00
# Family_MicroGame (Metagaming)                                             0.000000e+00
# Family_Micro Line (Stronghold)                                            0.000000e+00
# Family_Mice and Mystics                                                   0.000000e+00
# Family_MINNYS (Nürnberger-Spielkarten-Verlag)                             0.000000e+00
# Family_MERCS Recon                                                        0.000000e+00
# Family_M.I.G. (Compete Now)                                               0.000000e+00
# Family_Lynnvander Legacy Lin                                              0.000000e+00
# Family_Lunchbox Games (Fundex)                                            0.000000e+00
# Family_Mad Scientist (Blue Orange Games)                                  0.000000e+00
# Family_Lost Worlds (Nova Game Designs)                                    0.000000e+00
# Family_Lost Legacy                                                        0.000000e+00
# Family_Lost Cities                                                        0.000000e+00
# Family_Lorenzo il Magnifico                                               0.000000e+00
# Family_Lords of War (Black Box)                                           0.000000e+00
# Family_Marvel Champions – The Card                                        0.000000e+00
# Family_Martian Gardeners (nestorgames)                                    0.000000e+00
# Family_Lords of Hellas                                                    0.000000e+00
# Family_Loony Quest                                                        0.000000e+00
# Family_Market Garden (Paul Koenig)                                        0.000000e+00
# Family_Match Games (moses Verlag)                                         0.000000e+00
# Family_Mastermind                                                         0.000000e+00
# Family_Master Print Pocket (Quined)                                       0.000000e+00
# Family_Master Moves (TSR)                                                 0.000000e+00
# Family_Massive Darkness                                                   0.000000e+00
# Family_Marvel Crisis Protocol                                             0.000000e+00
# Family_Mitbringspiele (HABA)                                              0.000000e+00
# Family_Mission Command (Milton Bradley)                                   0.000000e+00
# Family_Mars and Venus                                                     0.000000e+00
# Family_Modern Line (Valley Games)                                         0.000000e+00
# Family_Mark H. Walker's Platoon Command                                   0.000000e+00
# Family_Mapomino                                                           0.000000e+00
# Family_Mamma Mia!                                                         0.000000e+00
# Family_Make 'n' Break                                                     0.000000e+00
# Family_Magus                                                              0.000000e+00
# Family_Magic The Gathering                                                0.000000e+00
# Family_Magic Maz                                                          0.000000e+00
# Family_Mage Wars                                                          0.000000e+00
# Family_Party & Co                                                         0.000000e+00
# Family_Operation                                                          0.000000e+00
# Family_Once Upon a Ti                                                     0.000000e+00
# Family_Paul Koenig's D-Day (Victory Point Games)                          0.000000e+00
# Family_Pathfinder Adventure Card Game (Paizo Publishing)                  0.000000e+00
# Family_Patchwork                                                          0.000000e+00
# Family_Passe Trapp                                                        0.000000e+00
# Family_Pass the Popcorn (Wiggles 3D)                                      0.000000e+00
# Family_Pass the Pigs                                                      0.000000e+00
# Family_Pass the Bomb                                                      0.000000e+00
# Family_Operational Combat Series (MMP)                                    0.000000e+00
# Family_Parody (Hasbro)                                                    0.000000e+00
# Family_Panzergruppe Guderian System (SPI)                                 0.000000e+00
# Family_PanzerBlitz (Avalon Hill)                                          0.000000e+00
# Family_ONUS! (Draco Ideas)                                                0.000000e+00
# Family_Numbered Series (MS Jogos)                                         0.000000e+00
# Family_Nuclear War (FBI)                                                  0.000000e+00
# Family_Noris-Fernsehspiele (Noris-Spiele)                                 0.000000e+00
# Family_Noris' Fantasy trilogy (Noris Spiele)                              0.000000e+00
# Family_NonSens                                                            0.000000e+00
# Family_Petrichor                                                          0.000000e+00
# Family_Panzer game system (Yaquinto/GMT)                                  0.000000e+00
# Family_Panzer Korps (Epoch / Command magazine Japan.)                     0.000000e+00
# Family_Panzer Grenadier (Avalanche)                                       0.000000e+00
# Family_Panzer General (Petroglyph)                                        0.000000e+00
# Family_Picturek                                                           0.000000e+00
# Family_Picture Book Games (Nova Game Designs)                             0.000000e+00
# Family_Pictionary                                                         0.000000e+00
# Family_Phoenix Command                                                    0.000000e+00
# Family_Phase 10                                                           0.000000e+00
# Family_Pairs Game System (Cheapass Games)                                 0.000000e+00
# Family_Personal Spac                                                      0.000000e+00
# Family_Perplexus                                                          0.000000e+00
# Family_Perpetual Commotion                                                0.000000e+00
# Family_Perfection (Lakeside Industries)                                   0.000000e+00
# Family_Pentago                                                            0.000000e+00
# Family_Penny Papers Adventures (Sit Down!)                                0.000000e+00
# Family_Operational System (GMT)                                           0.000000e+00
# Family_Operational Scale System (Compass Games)                           0.000000e+00
# Family_Next War (GMT)                                                     0.000000e+00
# Family_Obsession                                                          0.000000e+00
# Family_My Very First Games (HABA)                                         0.000000e+00
# Family_Muskets & Tomahawks (Studio Tomahawk)                              0.000000e+00
# Family_Musket & Pike Battle (GMT/Vae Victis)                              0.000000e+00
# Family_Museum (Holy Grail Games)                                          0.000000e+00
# Family_Nobody Is Perfect                                                  0.000000e+00
# Family_No Peace Without Spain (Compass Games)                             0.000000e+00
# Family_Nightfall                                                          0.000000e+00
# Family_Night of Man (Flying Pig Games)                                    0.000000e+00
# Family_Obstgarten (HABA)                                                  0.000000e+00
# Family_Never Have I Ever                                                  0.000000e+00
# Family_Netrunner                                                          0.000000e+00
# Family_Nemesis                                                            0.000000e+00
# Family_Naval Battl                                                        0.000000e+00
# Family_Nature of the Beast                                                0.000000e+00
# Family_Monopoly (Official)                                                0.000000e+00
# Family_Mondo (Pegasus Spiele)                                             0.000000e+00
# Family_Mombas                                                             0.000000e+00
# Family_Nations at War (Lock 'n Load Publishing)                           0.000000e+00
# Family_Pacru                                                              0.000000e+00
# Family_Pack O Game (Perplext)                                             0.000000e+00
# Family_PRESTAGS (SPI)                                                     0.000000e+00
# Family_PARK                                                               0.000000e+00
# Family_Outrider                                                           0.000000e+00
# Family_Outburst                                                           0.000000e+00
# Family_Osprey Wargam                                                      0.000000e+00
# Family_Orléans                                                            0.000000e+00
# Family_Origins (Jim Dunnigan)                                             0.000000e+00
# Family_Small City Trilogy (Alban Viard)                                   0.000000e+00
# Family_Napoleonic Wars (GMT)                                              0.000000e+00
# Family_Omen A Reign of War                                                0.000000e+00
# Family_Ology board games (Templar Publishing / Candlewick Press)          0.000000e+00
# Family_Old School Tactical (Flying Pig Games)                             0.000000e+00
# Family_Okko                                                               0.000000e+00
# Family_Ogre / G.E.V.                                                      0.000000e+00
# Family_Ogallala                                                           0.000000e+00
# Family_Odynaut                                                            0.000000e+00
# Family_Trickerion                                                         0.000000e+00
# Family_Tzolk'in – The Mayan Calendar                                      0.000000e+00
# Family_Two-Player Games (Gryphon Games)                                   0.000000e+00
# Family_Twister                                                            0.000000e+00
# Family_Twilight Imperiu                                                   0.000000e+00
# Family_Twenty Decisive Battles of the World (TPS)                         0.000000e+00
# Family_Trivial Pursuit – Editions Régionales (France)                     0.000000e+00
# Family_Trivial Pursuit                                                    0.000000e+00
# Family_Triumph & Glory                                                    0.000000e+00
# Family_Trickster                                                          0.000000e+00
# Family_U-Build (Hasbro)                                                   0.000000e+00
# Family_Triangle System (Predrag Lazovic / Dragan Lazovic)                 0.000000e+00
# Family_Thunderston                                                        0.000000e+00
# Family_TriBond                                                            0.000000e+00
# Family_Tri-Ominos                                                         0.000000e+00
# Family_Treasure Hunter                                                    0.000000e+00
# Family_Traveller Customizable Card                                        0.000000e+00
# Family_Traveller (Ravensburger)                                           0.000000e+00
# Family_Transameric                                                        0.000000e+00
# Family_Tramways                                                           0.000000e+00
# Family_Universal Fighting Syst                                            0.000000e+00
# Family_Warhammer 40,000 (Seventh Edition)                                 0.000000e+00
# Family_Valley of the Kings                                                0.000000e+00
# Family_Valiant Defense (DVG)                                              0.000000e+00
# Family_Upon a Fabl                                                        0.000000e+00
# Family_Up Front                                                           0.000000e+00
# Family_Unsolved Case Fil                                                  0.000000e+00
# Family_Unser Lieblingsspiel (Georg Appl / Espenlaub)                      0.000000e+00
# Family_Unmatched                                                          0.000000e+00
# Family_Unlock! (Space Cowboys)                                            0.000000e+00
# Family_TrainSport                                                         0.000000e+00
# Family_Unicorn Glitterluck (HABA)                                         0.000000e+00
# Family_Unfair                                                             0.000000e+00
# Family_Undo (Pegasus Spiele)                                              0.000000e+00
# Family_Undaunted (Osprey Games)                                           0.000000e+00
# Family_Ugly Animals (Drei Magier)                                         0.000000e+00
# Family_Ubongo                                                             0.000000e+00
# Family_UNO                                                                0.000000e+00
# Family_To Go! games (Mattel)                                              0.000000e+00
# Family_Thinker games for one player (Clicker Spiele)                      0.000000e+00
# Family_The North Sea Trilogy (Garphill Games)                             0.000000e+00
# Family_The Networks                                                       0.000000e+00
# Family_The Mike Line (Grail Games)                                        0.000000e+00
# Family_Three cups (Tom Russell)                                           0.000000e+00
# Family_Three Colors Trilogy (nestorgames)                                 0.000000e+00
# Family_This War of Mine (Awaken Realms)                                   0.000000e+00
# Family_This Is Not a Test                                                 0.000000e+00
# Family_Third World War (GDW)                                              0.000000e+00
# Family_Third Reich (Avalon Hill and others)                               0.000000e+00
# Family_Tide of Iron                                                       0.000000e+00
# Family_Think (Ravensburger)                                               0.000000e+00
# Family_They Died With Their Boots On (Decision Games)                     0.000000e+00
# Family_Theomachy                                                          0.000000e+00
# Family_The Worst-Case Scenario                                            0.000000e+00
# Family_The World's Smallest Sports Games (Famous Games Company)           0.000000e+00
# Family_The Wonderful World of Disney Trivia (Mattel)                      0.000000e+00
# Family_The Ironclads (Yaquinto)                                           0.000000e+00
# Family_The Grizzled                                                       0.000000e+00
# Family_The Ung                                                            0.000000e+00
# Family_Tiny Epic (Gamelyn Games)                                          0.000000e+00
# Family_Tragedy Looper                                                     0.000000e+00
# ...
# Family_Early Railways (Winsome Games)                                     0.000000
# Family_Eagles of the Empire (Avalanche Press)                             0.000000
# Family_Yahtz                                                              0.000000
# Family_Dreamwars                                                          0.000000
# Family_Dragon Castl                                                       0.000000
# Family_Down in Flames (Dan Verssen)                                       0.000000
# Family_Double Blind (GDW)                                                 0.000000
# Family_Doomtown – Reloaded                                                0.000000
# Family_Don't Quote M                                                      0.000000
# Family_Dominata                                                           0.000000
# Family_Dolmen                                                             0.000000
# Family_Doctor Who – Time of the Daleks                                    0.000000
# Family_Doctor Lucky                                                       0.000000
# Family_Empire of the Sun (RBM Studio)                                     0.000000
# Family_Dwar7                                                              0.000000
# Family_Dust (Fantasy Flight Games)                                        0.000000
# Family_Duo Collection (Matagot)                                           0.000000
# Family_Dungeons & Dragons Adventure System Board Gam                      0.000000
# Family_Dungeonology – The Expedition                                      0.000000
# Family_En Pointe Toujours system (Vae Victis)                             0.000000
# Family_Empires of the Void                                                0.000000
# Family_Empires of Apocalypse (Udo Grebe Gamedesign)                       0.000000
# Family_Empires (Glenn Drover)                                             0.000000
# Family_Escape Room – The Game (Identity Games International B.V.)         0.000000
# Family_Dungeon Drop                                                       0.000000
# Family_Dungeon Command                                                    0.000000
# Family_Duelist Library (Level 99 Games)                                   0.000000
# Family_Duel of Ages                                                       0.000000
# Family_Duel in the Dark                                                   0.000000
# Family_Duel (Clipper)                                                     0.000000
# Family_DrunkQuest                                                         0.000000
# Family_Drei Magier ghost gam                                              0.000000
# Family_First Battle (GDW)                                                 0.000000
# Family_G.A.S.L.I.G.H.T.                                                   0.000000
# Family_Fury of Dracul                                                     0.000000
# Family_Fur Zwei Spieler (Lookout Games)                                   0.000000
# Family_Funkoverse Strategy Game – Harry Potter                            0.000000
# Family_Funkoverse Strategy Game – DC Comics                               0.000000
# Family_Fun in a Box Collection (Foxmind)                                  0.000000
# Family_Fun For 2 (Ravensburger)                                           0.000000
# Family_Flames of War                                                      0.000000
# Family_Five Tribes                                                        0.000000
# Family_Five Parsecs (Nordic Weasel Games)                                 0.000000
# Family_Flintloqu                                                          0.000000
# Family_Fireteam Zero                                                      0.000000
# Family_Firestorm Galaxy                                                   0.000000
# Family_Firestorm Campaigns (Flames of War)                                0.000000
# Family_Firefly – The                                                      0.000000
# Family_Firefly Adventures                                                 0.000000
# Family_Fortune and Glory                                                  0.000000
# Family_Fighting Wings (J.D. Webster)                                      0.000000
# Family_Forgotten Axis (Decision Games)                                    0.000000
# Family_Forbidden Games (Gamewright)                                       0.000000
# Family_For the Story (Bragelonne Games)                                   0.000000
# Family_Games to go (Parker)                                               0.000000
# Family_Front Series (Columbia)                                            0.000000
# Family_Freitag-Project (Friedemann Friese)                                0.000000
# Family_Freedom From Gadgets (Yes Papa Games)                              0.000000
# Family_Free PnP during 2019-2020 COVID-19 Pandemic (Asmodee)              0.000000
# Family_Franco-Prussian War System (SPI)                                   0.000000
# Family_Four Against Darkness                                              0.000000
# Family_General (Frontline)                                                0.000000
# Family_Gemblo                                                             0.000000
# Family_Geistesblitz                                                       0.000000
# Family_Gamut of Games (Sid Sackson)                                       0.000000
# Family_Formula Dé / Formula D                                             0.000000
# Family_Games for Dumm                                                     0.000000
# Family_Games for 2 (Eurogames)                                            0.000000
# Family_Foodfighters                                                       0.000000
# Family_Folio (One Small Step)                                             0.000000
# Family_Folio (Decision Games)                                             0.000000
# Family_Fog of Lov                                                         0.000000
# Family_Flying Colors (GMT)                                                0.000000
# Family_Fluxx                                                              0.000000
# Family_Flipsiders (Milton Bradley)                                        0.000000
# Family_Flip City                                                          0.000000
# Family_Eye Found It!                                                      0.000000
# Family_Family Games (Gryphon Games)                                       0.000000
# Family_Express Line (Hasbro)                                              0.000000
# Family_Flamme Roug                                                        0.000000
# Family_Flash Point Fire Rescu                                             0.000000
# Family_Fleet                                                              0.000000
# Family_Expert (Granna)                                                    0.000000
# Family_Fleet (Victory Games)                                              0.000000
# Family_Fleet Commander                                                    0.000000
# Family_Exit – The Gam                                                     0.000000
# Family_Flick 'em Up                                                       0.000000
# Family_Fireball Island                                                    0.000000
# Family_Fire & Movement combat system (Decision Games)                     0.000000
# Family_FlightPath (Fantasy Flight Game)                                   0.000000
# Family_Fallout                                                            0.000000
# Family_Farkl                                                              0.000000
# Family_Fable Game system                                                  0.000000
# Family_Fast Action Battles (FAB)                                          0.000000
# Family_Final Girl                                                         0.000000
# Family_Fate of the Elder Gods                                             0.000000
# Family_Federation & Empir                                                 0.000000
# Family_Federation Commander                                               0.000000
# Family_Ferti Sugo                                                         0.000000
# Family_FITS                                                               0.000000
# Family_Feudu                                                              0.000000
# Family_Fex (HABA)                                                         0.000000
# Family_Field Commander (DVG)                                              0.000000
# Family_For What Remain                                                    0.000000
# Family_For the Crown                                                      0.000000
# Family_Filosofia Reprint                                                  0.000000
# Family_Eye to Ey                                                          0.000000
# Family_Zarcana-typ                                                        0.002993
# Family_Basic (Gigamic)                                                    0.003849
# Family_Yokoh                                                              0.004799
# ComMaxPlaytime                                                            0.005985
# MfgPlaytime                                                               0.005985
# Family_30 Journeys (Thundergryph)                                         0.013795
# Family_Dixit                                                              0.015787
# Family_Leader (DVG)                                                       0.015927
# Family_Postcard Box Games (Indie Boards and Cards)                        0.023108
# Family_7 Wonders                                                          0.027458
# Family_No Retreat! (Carl Paradis)                                         0.029447
# Family_Troyes                                                             0.031723
# Family_MicroMacro                                                         0.034238
# MfgAgeRec                                                                 0.036112
# Family_Space Empires 4X                                                   0.036250
# YearPeriod_2010s                                                          0.039282
# Family_Time's Up!                                                         0.039979
# Family_Small Box (Queen)                                                  0.040574
# Family_Master Print Edition (Quined)                                      0.041599
# Family_Race for the Galaxy                                                0.043550
# Family_Love Letter                                                        0.044974
# Family_Istanbul (AEG)                                                     0.045038
# Family_St                                                                 0.047492
# Family_Specialist Games (Games Workshop)                                  0.049444
# Family_Bruxelles 189X                                                     0.049675
# Family_Lunchtime Games (GMT)                                              0.054862
# Family_Levy & Campaign (GMT)                                              0.055896
# Family_COIN (GMT)                                                         0.069021
# Family_Key (Richard Breese)                                               0.071257
# Family_Thurn and Taxis                                                    0.072949
# Family_Alea Big Box                                                       0.074056
# Family_The Hunt                                                           0.074551
# Family_Rondel (Mac Gerdts)                                                0.076983
# Family_Hanabi                                                             0.077273
# Family_States of Sieg                                                     0.077276
# Family_Conflict of Heroes (Academy Games)                                 0.081931
# Family_Concordi                                                           0.084463
# Family_Boggl                                                              0.085788
# Family_Fantasy Flight Silver Lin                                          0.086449
# Family_Book Box (DiceTree)                                                0.089767
# Family_Treefrog Line (Warfrog)                                            0.090226
# Family_Yellow Wave Box (Queen)                                            0.090521
# Family_Coloretto                                                          0.090551
# Family_Splendor                                                           0.094590
# Family_Mitbringspiel Mini (HABA)                                          0.099088
# Family_Lords of Waterdeep                                                 0.099210
# Family_Warfighter (DVG)                                                   0.100182
# Family_Blue Moon                                                          0.100475
# Family_Alea Revised Big Box                                               0.105093
# IsReimplementation                                                        0.105957
# Family_Combat Command                                                     0.106382
# YearPeriod_2000s                                                          0.110412
# Family_The Crew                                                           0.110588
# Family_Euro Classics (Reiner Knizia)                                      0.116711
# Family_Saint Petersburg                                                   0.118125
# Family_Small box (Lautapelit.fi)                                          0.126183
# Family_Cosmic Encounter                                                   0.128304
# Family_5 Minute Fun (AEG)                                                 0.128321
# Family_International Games (MMP)                                          0.129618
# Family_A Victory Lost                                                     0.139957
# Family_Madison Game Design Cabal                                          0.141277
# Family_El Grand                                                           0.148381
# Family_Cube Rail                                                          0.151741
# YearPeriod_2020s                                                          0.156694
# Family_Age of St                                                          0.159056
# Family_HoldFast (Worthington Publishing)                                  0.159800
# Family_Deluxe card game (Z-Man / Filosofia)                               0.182743
# Family_Alea Medium Box                                                    0.189879
# Family_Dominion                                                           0.190361
# Family_Two-player games (Kosmos)                                          0.202617
# NumImplementations                                                        0.202916
# Family_Hanamikoji                                                         0.204804
# Family_Shadows over Camelot                                               0.218002
# Family_Nemo's War                                                         0.222247
# Cat:Party                                                                 0.249958
# Family_Two-player games (Space Cowboys)                                   0.251283
# Family_18xx                                                               0.266350
# Family_Great Battles of History (GMT Games)                               0.277350
# Family_Ticket to Ride (Official)                                          0.316151
# Family_Bookshelf (Gryphon Games)                                          0.349433
# Cat:War                                                                   0.367362
# Cat:Abstract                                                              0.468936
# Cat:Strategy                                                              0.481292
# NumAlternates                                                             0.559509
# GameWeight                                                                1.011604

# %%
#LINEAR REGRESSION - 2
#Vamos a hacer un ranking de los juegos que me podrian gustar más.
#Fijaremos más adelante el umbral. De momento hagamos un TOP 20
#Vamoa a preparar los siguientes datos
#X_train = la matriz de mis juegos puntuados, que son los datos de entrenamiento
#y_train = la puntuación dado a cada uno de los juegos que tengo puntuados.
#X_nuevos = la matriz de juegos de Kagle que NO tengo

features = ['GameWeight', 'MinPlayers', 'MaxPlayers', 'MfgPlaytime',
            'ComMinPlaytime', 'ComMaxPlaytime', 'ComAgeRec', 'LanguageEase',
            'Cat:Thematic', 'Cat:Strategy', 'Cat:War', 'Cat:Family',
            'Cat:CGS', 'Cat:Abstract', 'Cat:Party', 'Cat:Childrens']

# Todos los BGGId que ya tienes (puntuados o no) en tu colección
ids_luis = df_luis['BGGId']

# Candidatos: juegos de Kaggle que NO están en tu colección
df_recomendar = df_games[~df_games['BGGId'].isin(ids_luis)].copy()
print(f"Candidatos que pasamos para recomendar: {len(df_recomendar)}")

X_train = df_train[features]        # entrada de ENTRENAMIENTO (tus juegos base puntuados)
y_train = df_train['UserRating']    # objetivo: tus notas

X_nuevos = df_recomendar[features]  # entrada de PREDICCIÓN (los juegos que no tienes)

# este vector saca las medianas de todos los parámetros X del set de en0trenamiento
# Lo hacemos para normalizar los NaN datos de juegos que no tengo "X_nuevos"
# Un tema importante es que normalizamos con datos DE ENTRENAMIENTO. Nunca con datos de prediccion.
medianas_train = X_train.median()
X_nuevos = X_nuevos.fillna(medianas_train)

#Ahora tenemos los datos preparados, que son los siguientes
#X_train = la matriz de mis juegos puntuados, que son los datos de entrenamiento
#y_train = la puntuación dado a cada uno de los juegos que tengo puntuados.
#X_nuevos = la matriz de juegos de Kagle que NO tengo

#Pasamos el modelo
# La validación cruzada y el modelo final, ahora con los nombres nuevos
modelo_ridge = make_pipeline(StandardScaler(), Ridge(alpha=1.0))
scores_ridge = cross_val_score(modelo_ridge, X_train, y_train, cv=5,
                               scoring='neg_mean_absolute_error')
modelo_ridge.fit(X_train, y_train)

# Predecir la nota de cada juego candidato
df_recomendar['nota_predicha'] = modelo_ridge.predict(X_nuevos)

df_recomendar['posicion'] = df_recomendar['nota_predicha'] \
    .rank(ascending=False, method='min').astype(int)

MIN_VOTOS = 1000
#Generamos el ranking quitando los juegos con menos de MIN_VOTOS y ordenando de mayor a menor
# Filtramos SOLO al construir el ranking. df_recomendar queda intacto.
ranking = df_recomendar[df_recomendar['NumUserRatings'] >= MIN_VOTOS] \
              .sort_values('nota_predicha', ascending=False)



# Top 20 — mostramos las features que el modelo dijo que más te gustan,
# para que TÚ juzgues si las recomendaciones tienen sentido
columnas_a_ver = ["posicion", 'Name', 'nota_predicha', 'GameWeight', 'Cat:War', 'Cat:Strategy']
print(ranking[columnas_a_ver].head(20).to_string())



# Buscar juegos con "18" en el nombre dentro del ranking completo (sin filtrar por votos)
mask_18xx = df_recomendar['Name'].str.contains(r'^18\d\d', na=False, regex=True) \
            & (df_recomendar['Cat:War'] == 0)
cols = ["posicion", 'Name', 'nota_predicha', 'GameWeight', 'Cat:War', 'Cat:Strategy']
print(df_recomendar[mask_18xx].sort_values('nota_predicha', ascending=False)[cols].head(15).to_string())
# Out:
# Candidatos que pasamos para recomendar: 21232
#        posicion                                                               Name  nota_predicha  GameWeight  Cat:War  Cat:Strategy
# 16460         5                                                  Imperial Struggle      10.548025      3.8931        1             1
# 209           6                                              Advanced Squad Leader      10.540446      4.7321        1             0
# 18079        17                                                               Root      10.268692      3.7068        1             1
# 1187         31                                                 Star Fleet Battles      10.093229      4.1830        1             0
# 809          36                                                       Squad Leader      10.063063      4.0365        1             0
# 6733         62                              Advanced Squad Leader: Starter Kit #3       9.934680      3.9000        1             0
# 5944        131                              Advanced Squad Leader: Starter Kit #2       9.726153      3.7978        1             0
# 1571        139                                                             Bridge       9.711218      3.8562        0             1
# 4853        147                              Advanced Squad Leader: Starter Kit #1       9.696972      3.7547        1             0
# 12887       233                                            1944: Race to the Rhine       9.540437      2.9444        1             1
# 1117        280                                                    World in Flames       9.475836      4.6373        1             0
# 77          338                                               Rommel in the Desert       9.392895      3.4183        1             0
# 2730        351  Warhammer: The Mass Combat Fantasy Roleplaying Game (1st Edition)       9.378347      3.6992        1             0
# 493         374                                                           Up Front       9.354480      3.4113        1             0
# 1491        377                                            The Civil War 1861-1865       9.350419      3.8056        1             0
# 15663       379                                         Days of Ire: Budapest 1956       9.348828      2.8222        1             1
# 8913        387                                                              Maria       9.336896      3.5118        1             0
# 18811       405                                 Star Wars: X-Wing (Second Edition)       9.323796      3.0435        1             0
# 13812       407                                                             Feudum       9.319729      4.5937        0             1
# 17913       426                                                 Battle for Rokugan       9.302353      2.7500        1             1
#        posicion                                                Name  nota_predicha  GameWeight  Cat:War  Cat:Strategy
# 9163        420                  1812: The Cradle of Steam Railways       9.305575      4.4000        0             1
# 2168       1102                                                1899       8.890650      4.1667        0             1
# 2961       1136                                                1854       8.872726      4.2000        0             1
# 4188       1549  1837: Rail Building in the Austro-Hungarian Empire       8.675089      4.1875        0             1
# 6209       1924                                      1800: Colorado       8.516333      3.5714        0             1
# 984        2192   1826: Railroading in France and Belgium from 1826       8.410662      3.8571        0             1
# 18443      2253          1883: Building Railroads in Northern Italy       8.387090      4.1667        0             0
# 1086       2339                    1841: Railways in Northern Italy       8.352714      4.3947        0             1
# 19919      2495                                                1836       8.297019      4.0000        0             0
# 5780       2501                                       1829 Mainline       8.295100      4.0000        0             1
# 18857      2579                                                1834       8.264647      4.0000        0             0
# 908        2659                          1851: Kentucky & Tennessee       8.237056      3.2727        0             1
# 5234       2700                                        1895 Namibia       8.218144      3.2000        0             1
# 17510      2713                                                1868       8.214615      4.0000        0             0
# 14464      2844                                              1836Jr       8.156663      4.3333        0             0
